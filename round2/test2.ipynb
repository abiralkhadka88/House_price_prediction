# %%
import pandas as pd

# %%
df= pd.read_csv('cleaned_face.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Floors        City         Address       Land       Price  \
# 0           0     NaN   Kathmandu       Pepsicola   200.0000    500000.0
# 1           1    12.0    Lalitpur      Jhamsikhel   683.0000     40000.0
# 2           2     2.5   Kathmandu        Golfutar  1779.7000  43000000.0
# 3           3     NaN   Kathmandu  Budhanilkantha  1369.0000  35000000.0
# 4           4     NaN   Kathmandu      Dhumbarahi  2481.3125  51700000.0
#
#    Bedroom  Bathroom        Face  Road
# 0      0.0       0.0  south east   0.0
# 1      2.0       1.0       south   0.0
# 2      5.0       5.0        east   0.0
# 3      0.0       0.0  north east   0.0
# 4      0.0       0.0        east   0.0

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Floors        949
# City           12
# Address        12
# Land           19
# Price          42
# Bedroom       639
# Bathroom      792
# Face          647
# Road           68
# dtype: int64

# %%
df.dropna()
# Out:
#       Unnamed: 0  Floors        City     Address         Land       Price  \
# 1              1    12.0    Lalitpur  Jhamsikhel   683.000000     40000.0
# 2              2     2.5   Kathmandu    Golfutar  1779.700000  43000000.0
# 8              8     7.0   Kathmandu      Thamel    53.670000  95000000.0
# 12            12     4.0   Kathmandu      Balkhu  1796.812500  60000000.0
# 15            15     3.0   Kathmandu      Thamel  1369.000000  26000000.0
# ...          ...     ...         ...         ...          ...         ...
# 5257        5257     8.0   Kathmandu   Baneshwor  2200.000000    350000.0
# 5258        5258     3.0   Kathmandu   Koteshwor   900.000000     60000.0
# 5259        5259     4.0   Kathmandu     Kalanki  1796.812500  52500000.0
# 5260        5260     4.0   Kathmandu  Basundhara   523.986652  26000000.0
# 5261        5261     3.0    Lalitpur   Tikathali  3208.593750  40000000.0
#
#       Bedroom  Bathroom        Face   Road
# 1         2.0       1.0       south   0.00
# 2         5.0       5.0        east   0.00
# 8         0.0       0.0  north west   0.00
# 12        0.0       0.0       south   0.00
# 15        6.0       5.0        east   0.00
# ...       ...       ...         ...    ...
# 5257      0.0       0.0       south  98.43
# 5258      0.0       4.0        east  98.43
# 5259      0.0       0.0        west  19.00
# 5260      0.0       4.0       north  21.00
# 5261      4.0       4.0       south  30.00
#
# [3317 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

features = ['Price', 'Bathroom', 'Bedroom', 'Floors', 'Land']

mask = np.zeros_like(df[features].corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(10, 8))
plt.title('Pearson Correlation Matrix', fontsize=20)

sns.heatmap(df[features].corr(), linewidths=0.5, vmax=0.7, square=True, cmap="BuGn",
            linecolor='w', annot=True, annot_kws={"size": 8}, mask=mask, cbar_kws={"shrink": 0.9})

plt.savefig('correlation_matrix.png', dpi=300)
plt.show()
# Out:
# C:\Users\Abiral\AppData\Local\Temp\ipykernel_13272\371128712.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(df[features].corr(), dtype=np.bool)
