# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_gharbazars.csv')

# %%
df.head()
# Out:
#                                                price        LAND AREA
# 0         Rs. 40,000 (Negotiable)\n(Forty thousand )          0-4-0-0  \
# 1     Rs. 32,00,000 (Negotiable)\n(32 lakh per aana)          0-4-0-0
# 2                          Rs. 7,00,000 (Negotiable)  999 SQUARE FEET
# 3  Rs. 2,30,00,000 (Negotiable)\n(Two crore thirt...          0-4-2-2
# 4                         Rs. 28,00,000 (Negotiable)          0-4-0-0
#
#          HOUSE AREA  Unnamed: 3  BEDS  LIVING  KITCHEN  BATHROOMS  FLOORS
# 0  1200 SQUARE FEET         NaN   3.0     1.0      1.0        2.0     2.0  \
# 1               NaN         NaN   NaN     NaN      NaN        NaN     NaN
# 2               NaN         NaN   NaN     NaN      NaN        NaN     NaN
# 3  2100 SQUARE FEET         NaN   6.0     2.0      2.0        3.0     2.5
# 4               NaN         NaN   NaN     NaN      NaN        NaN     NaN
#
#                                     LOCATION  ...           TYPE     CODE
# ...

# %%
df.columns
# Out:
# Index(['price', 'LAND AREA', 'HOUSE AREA', 'Unnamed: 3', 'BEDS', 'LIVING',
#        'KITCHEN', 'BATHROOMS', 'FLOORS', 'LOCATION', 'ROAD DESCRIPTION',
#        'FACED TOWARDS', 'CATEGORY', 'TYPE', 'CODE', 'UPDATE', 'VIEWS',
#        'FURNISHING', 'url', 'MAIN ROAD DISTANCE', 'ROAD TO HOUSE', 'FLAT AREA',
#        'PARKING AREA'],
#       dtype='object')

# %%
columns_to_drop = ['Unnamed: 3','CATEGORY','TYPE','CODE','UPDATE','VIEWS','FURNISHING','url','FLAT AREA','PARKING AREA']

# %%
df =df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               540 non-null    object
#  1   LAND AREA           587 non-null    object
#  2   HOUSE AREA          177 non-null    object
#  3   BEDS                315 non-null    float64
#  4   LIVING              276 non-null    float64
#  5   KITCHEN             301 non-null    float64
#  6   BATHROOMS           240 non-null    float64
#  7   FLOORS              311 non-null    float64
#  8   LOCATION            596 non-null    object
#  9   ROAD DESCRIPTION    569 non-null    object
#  10  FACED TOWARDS       607 non-null    object
#  11  MAIN ROAD DISTANCE  204 non-null    object
#  12  ROAD TO HOUSE       187 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 62.6+ KB

# %%
df
# Out:
#                                                  price        LAND AREA
# 0           Rs. 40,000 (Negotiable)\n(Forty thousand )          0-4-0-0  \
# 1       Rs. 32,00,000 (Negotiable)\n(32 lakh per aana)          0-4-0-0
# 2                            Rs. 7,00,000 (Negotiable)  999 SQUARE FEET
# 3    Rs. 2,30,00,000 (Negotiable)\n(Two crore thirt...          0-4-2-2
# 4                           Rs. 28,00,000 (Negotiable)          0-4-0-0
# ..                                                 ...              ...
# 610  Rs. 28,00,000 (Negotiable)\n(Twenty eight lakh...          0-3-2-0
# 611  Rs. 3,00,000 (Negotiable)\n(Three lakh per rop...         15-0-0-0
# 612  Rs. 3,50,000 (Negotiable)\n(Three lakh fifty t...         13-8-0-0
# 613  Rs. 8,99,00,000 (Negotiable)\n(Eight crore nin...         3 KATTHA
# 614  Rs. 1,60,000 (Negotiable)\n(One lakh sixty tho...               0-
#
#            HOUSE AREA  BEDS  LIVING  KITCHEN  BATHROOMS  FLOORS
# ...

# %%
df = df.drop(columns=['ROAD TO HOUSE','MAIN ROAD DISTANCE'])

# %%
df
# Out:
#                                                  price        LAND AREA
# 0           Rs. 40,000 (Negotiable)\n(Forty thousand )          0-4-0-0  \
# 1       Rs. 32,00,000 (Negotiable)\n(32 lakh per aana)          0-4-0-0
# 2                            Rs. 7,00,000 (Negotiable)  999 SQUARE FEET
# 3    Rs. 2,30,00,000 (Negotiable)\n(Two crore thirt...          0-4-2-2
# 4                           Rs. 28,00,000 (Negotiable)          0-4-0-0
# ..                                                 ...              ...
# 610  Rs. 28,00,000 (Negotiable)\n(Twenty eight lakh...          0-3-2-0
# 611  Rs. 3,00,000 (Negotiable)\n(Three lakh per rop...         15-0-0-0
# 612  Rs. 3,50,000 (Negotiable)\n(Three lakh fifty t...         13-8-0-0
# 613  Rs. 8,99,00,000 (Negotiable)\n(Eight crore nin...         3 KATTHA
# 614  Rs. 1,60,000 (Negotiable)\n(One lakh sixty tho...               0-
#
#            HOUSE AREA  BEDS  LIVING  KITCHEN  BATHROOMS  FLOORS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             540 non-null    object
#  1   LAND AREA         587 non-null    object
#  2   HOUSE AREA        177 non-null    object
#  3   BEDS              315 non-null    float64
#  4   LIVING            276 non-null    float64
#  5   KITCHEN           301 non-null    float64
#  6   BATHROOMS         240 non-null    float64
#  7   FLOORS            311 non-null    float64
#  8   LOCATION          596 non-null    object
#  9   ROAD DESCRIPTION  569 non-null    object
#  10  FACED TOWARDS     607 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 53.0+ KB

# %%
df.dropna()
# Out:
#                                                  price          LAND AREA
# 0           Rs. 40,000 (Negotiable)\n(Forty thousand )            0-4-0-0  \
# 3    Rs. 2,30,00,000 (Negotiable)\n(Two crore thirt...            0-4-2-2
# 14   Rs. 3,20,00,000 (Negotiable)\n(Three crore twe...            0-6-0-0
# 17   Rs. 2,85,00,000 (Negotiable)\n(Two crore eight...            0-4-1-1
# 29   Rs. 2,15,00,000 (Negotiable)\n(Two crore fifte...            0-3-3-0
# ..                                                 ...                ...
# 549  Rs. 70,000 (Negotiable)\n(Seventy thousand per...   1275 SQUARE FEET
# 562  Rs. 2,40,00,000 (Negotiable)\n(Two crore forty...            0-4-0-0
# 573    Rs. 1,35,00,000 (Negotiable)\n(1 crore 35 lakh)            0-4-0-0
# 584  Rs. 2,40,00,000 (Negotiable)\n(Two crore forty...  1369 SQUARE METER
# 606  Rs. 1,35,00,000 (Negotiable)\n(One crore thirt...            0-2-2-2
#
#             HOUSE AREA  BEDS  LIVING  KITCHEN  BATHROOMS  FLOORS
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame called 'df'
has_zeros = (df == 0).any().any()

if has_zeros:
    print("The DataFrame contains 0 values.")
else:
    print("The DataFrame does not contain any 0 values.")
# Out:
# The DataFrame does not contain any 0 values.
