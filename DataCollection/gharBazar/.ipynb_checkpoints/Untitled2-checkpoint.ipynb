# %%
import pandas as pd

# %%
df= pd.read_csv('up_house.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Address   122 non-null    object
#  1   Land      122 non-null    float64
#  2   Road      122 non-null    int64
#  3   Price     122 non-null    int64
#  4   Bedroom   122 non-null    int64
#  5   Bathroom  122 non-null    int64
#  6   Face      122 non-null    object
#  7   Floors    122 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.8+ KB

# %%
df['Address'] = df['Address'].str.replace(', NEPAL', '')

print(df)
# Out:
#                               Address     Land  Road      Price  Bedroom
# 0                 LAGANKHEL, LALITPUR  1197.87    20    8000000        3  \
# 1      SCHOOL CHOWK, IMADOL, LALITPUR  1283.43    18    9500000        2
# 2      KHADKAGAUN, KALANKI, KATHMANDU  1882.37    16   12000000        6
# 3                 GOTHATAR, KATHMANDU   898.40    13   12500000        4
# 4                  GOKARNA, KATHMANDU  1369.00    15   13500000        4
# ..                                ...      ...   ...        ...      ...
# 117  BASANTA NAGAR, BALAJU, KATHMANDU  3422.50    16   55000000        7
# 118                  SANEPA, LALITPUR  1711.25    13   63500000        5
# 119             BASUNDHARA, KATHMANDU  2395.75    13   72500000        9
# 120          KUNWAR COLONY, KATHMANDU  4791.50    20   75000000        5
# 121  DHUNGEDHARA, DHOBIGHAT, LALITPUR  6845.00    16  100000000        4
#
#      Bathroom        Face  Floors
# 0           3       North     3.0
# ...

# %%
# Assuming you have a DataFrame called 'df'
df['district'] = df['Address'].str.split(',').str[-1]

print(df)
# Out:
#                               Address     Land  Road      Price  Bedroom
# 0                 LAGANKHEL, LALITPUR  1197.87    20    8000000        3  \
# 1      SCHOOL CHOWK, IMADOL, LALITPUR  1283.43    18    9500000        2
# 2      KHADKAGAUN, KALANKI, KATHMANDU  1882.37    16   12000000        6
# 3                 GOTHATAR, KATHMANDU   898.40    13   12500000        4
# 4                  GOKARNA, KATHMANDU  1369.00    15   13500000        4
# ..                                ...      ...   ...        ...      ...
# 117  BASANTA NAGAR, BALAJU, KATHMANDU  3422.50    16   55000000        7
# 118                  SANEPA, LALITPUR  1711.25    13   63500000        5
# 119             BASUNDHARA, KATHMANDU  2395.75    13   72500000        9
# 120          KUNWAR COLONY, KATHMANDU  4791.50    20   75000000        5
# 121  DHUNGEDHARA, DHOBIGHAT, LALITPUR  6845.00    16  100000000        4
#
#      Bathroom        Face  Floors    district
# ...

# %%
df
# Out:
#                               Address     Land  Road      Price  Bedroom
# 0                 LAGANKHEL, LALITPUR  1197.87    20    8000000        3  \
# 1      SCHOOL CHOWK, IMADOL, LALITPUR  1283.43    18    9500000        2
# 2      KHADKAGAUN, KALANKI, KATHMANDU  1882.37    16   12000000        6
# 3                 GOTHATAR, KATHMANDU   898.40    13   12500000        4
# 4                  GOKARNA, KATHMANDU  1369.00    15   13500000        4
# ..                                ...      ...   ...        ...      ...
# 117  BASANTA NAGAR, BALAJU, KATHMANDU  3422.50    16   55000000        7
# 118                  SANEPA, LALITPUR  1711.25    13   63500000        5
# 119             BASUNDHARA, KATHMANDU  2395.75    13   72500000        9
# 120          KUNWAR COLONY, KATHMANDU  4791.50    20   75000000        5
# 121  DHUNGEDHARA, DHOBIGHAT, LALITPUR  6845.00    16  100000000        4
#
#      Bathroom        Face  Floors    district
# ...

# %%
df['Address'] = df['Address'].str.split(',')

# %%
df['Address']
# Out:
# 0                    [LAGANKHEL,  LALITPUR]
# 1        [SCHOOL CHOWK,  IMADOL,  LALITPUR]
# 2        [KHADKAGAUN,  KALANKI,  KATHMANDU]
# 3                    [GOTHATAR,  KATHMANDU]
# 4                     [GOKARNA,  KATHMANDU]
#                        ...
# 117    [BASANTA NAGAR,  BALAJU,  KATHMANDU]
# 118                     [SANEPA,  LALITPUR]
# 119                [BASUNDHARA,  KATHMANDU]
# 120             [KUNWAR COLONY,  KATHMANDU]
# 121    [DHUNGEDHARA,  DHOBIGHAT,  LALITPUR]
# Name: Address, Length: 122, dtype: object

# %%
df['Address'] = df['Address'].apply(lambda x: x[:-1])

# %%
df['Address']
# Out:
# 0                    [LAGANKHEL]
# 1        [SCHOOL CHOWK,  IMADOL]
# 2         [KHADKAGAUN,  KALANKI]
# 3                     [GOTHATAR]
# 4                      [GOKARNA]
#                  ...
# 117     [BASANTA NAGAR,  BALAJU]
# 118                     [SANEPA]
# 119                 [BASUNDHARA]
# 120              [KUNWAR COLONY]
# 121    [DHUNGEDHARA,  DHOBIGHAT]
# Name: Address, Length: 122, dtype: object

# %%
df['Address'] = df['Address'].apply(lambda x: x[1:] if len(x) == 2 else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Address   122 non-null    object
#  1   Land      122 non-null    float64
#  2   Road      122 non-null    int64
#  3   Price     122 non-null    int64
#  4   Bedroom   122 non-null    int64
#  5   Bathroom  122 non-null    int64
#  6   Face      122 non-null    object
#  7   Floors    122 non-null    float64
#  8   district  122 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.7+ KB

# %%
df2= pd.read_csv('cleaned_gharbazar.csv')

# %%
df2
# Out:
#                Address     Land  Road      Price  Bedroom  Bathroom
# 0        ['LAGANKHEL']  1197.87    20    8000000        3         3  \
# 1          [' IMADOL']  1283.43    18    9500000        2         1
# 2         [' KALANKI']  1882.37    16   12000000        6         5
# 3         ['GOTHATAR']   898.40    13   12500000        4         2
# 4          ['GOKARNA']  1369.00    15   13500000        4         2
# ..                 ...      ...   ...        ...      ...       ...
# 117        [' BALAJU']  3422.50    16   55000000        7         2
# 118         ['SANEPA']  1711.25    13   63500000        5         6
# 119     ['BASUNDHARA']  2395.75    13   72500000        9         6
# 120  ['KUNWAR COLONY']  4791.50    20   75000000        5         5
# 121     [' DHOBIGHAT']  6845.00    16  100000000        4         2
#
#            Face  Floors    district
# 0         North     3.0    LALITPUR
# 1          West     1.5    LALITPUR
# 2         North     2.5   KATHMANDU
# ...

# %%
df2.drop(columns='Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df2.drop(columns='Unnamed: 0')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# ...

# %%
df2.to_csv('cleaned_gharbazar.csv',index= False)

# %%
df3= pd.read_csv('cleaned_gharbazar.csv')

# %%
df3
# Out:
#      Unnamed: 0            Address     Land  Road      Price  Bedroom
# 0             0      ['LAGANKHEL']  1197.87    20    8000000        3  \
# 1             1        [' IMADOL']  1283.43    18    9500000        2
# 2             2       [' KALANKI']  1882.37    16   12000000        6
# 3             3       ['GOTHATAR']   898.40    13   12500000        4
# 4             4        ['GOKARNA']  1369.00    15   13500000        4
# ..          ...                ...      ...   ...        ...      ...
# 117         117        [' BALAJU']  3422.50    16   55000000        7
# 118         118         ['SANEPA']  1711.25    13   63500000        5
# 119         119     ['BASUNDHARA']  2395.75    13   72500000        9
# 120         120  ['KUNWAR COLONY']  4791.50    20   75000000        5
# 121         121     [' DHOBIGHAT']  6845.00    16  100000000        4
#
#      Bathroom        Face  Floors    district
# 0           3       North     3.0    LALITPUR
# ...

# %%
df2.to_csv('cleaned_gharbazar.csv', index=False, columns=df2.columns[1:])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Address   122 non-null    object
#  1   Land      122 non-null    float64
#  2   Road      122 non-null    int64
#  3   Price     122 non-null    int64
#  4   Bedroom   122 non-null    int64
#  5   Bathroom  122 non-null    int64
#  6   Face      122 non-null    object
#  7   Floors    122 non-null    float64
#  8   district  122 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.7+ KB

# %%
df
# Out:
#              Address     Land  Road      Price  Bedroom  Bathroom        Face
# 0        [LAGANKHEL]  1197.87    20    8000000        3         3       North  \
# 1          [ IMADOL]  1283.43    18    9500000        2         1        West
# 2         [ KALANKI]  1882.37    16   12000000        6         5       North
# 3         [GOTHATAR]   898.40    13   12500000        4         2        East
# 4          [GOKARNA]  1369.00    15   13500000        4         2        East
# ..               ...      ...   ...        ...      ...       ...         ...
# 117        [ BALAJU]  3422.50    16   55000000        7         2       South
# 118         [SANEPA]  1711.25    13   63500000        5         6  North East
# 119     [BASUNDHARA]  2395.75    13   72500000        9         6        East
# 120  [KUNWAR COLONY]  4791.50    20   75000000        5         5        East
# 121     [ DHOBIGHAT]  6845.00    16  100000000        4         2        East
#
#      Floors    district
# ...

# %%
df2['Address'] = df2['Address'].str.strip('[]')

# %%
df2['Address']
# Out:
# 0          'LAGANKHEL'
# 1            ' IMADOL'
# 2           ' KALANKI'
# 3           'GOTHATAR'
# 4            'GOKARNA'
#             ...
# 117          ' BALAJU'
# 118           'SANEPA'
# 119       'BASUNDHARA'
# 120    'KUNWAR COLONY'
# 121       ' DHOBIGHAT'
# Name: Address, Length: 122, dtype: object

# %%
df2.to_csv('cleaned_gharbazar.csv', index=False)

# %%
df2['Address'] = df2['Address'].str.strip("'")

# %%
df2
# Out:
#            Address     Land  Road      Price  Bedroom  Bathroom        Face
# 0        LAGANKHEL  1197.87    20    8000000        3         3       North  \
# 1           IMADOL  1283.43    18    9500000        2         1        West
# 2          KALANKI  1882.37    16   12000000        6         5       North
# 3         GOTHATAR   898.40    13   12500000        4         2        East
# 4          GOKARNA  1369.00    15   13500000        4         2        East
# ..             ...      ...   ...        ...      ...       ...         ...
# 117         BALAJU  3422.50    16   55000000        7         2       South
# 118         SANEPA  1711.25    13   63500000        5         6  North East
# 119     BASUNDHARA  2395.75    13   72500000        9         6        East
# 120  KUNWAR COLONY  4791.50    20   75000000        5         5        East
# 121      DHOBIGHAT  6845.00    16  100000000        4         2        East
#
#      Floors    district
# 0       3.0    LALITPUR
# ...

# %%
df2.to_csv('cleaned_gharbazar.csv', index=False)
