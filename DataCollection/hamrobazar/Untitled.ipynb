# %%
import pandas as pd

# %%
df1= pd.read_csv('remaining.csv')

# %%
df2 = pd.read_csv('hamrobazar2.csv')

# %%
df1
# Out:
#      Unnamed: 0                                                URL
# 0           721  https://hamrobazaar.com/for-sale-house/flat-sy...
# 1           722  https://hamrobazaar.com/for-sale-house/25-tall...
# 2           723  https://hamrobazaar.com/for-sale-house/samakhu...
# 3           724  https://hamrobazaar.com/for-sale-house/house-o...
# 4           725  https://hamrobazaar.com/for-sale-house/ghar-ko...
# ..          ...                                                ...
# 232         953  https://hamrobazaar.com/for-sale-house/house-o...
# 233         954  https://hamrobazaar.com/for-sale-house/house-f...
# 234         955  https://hamrobazaar.com/for-sale-house/for-sel...
# 235         956  https://hamrobazaar.com/for-sale-house/imadol-...
# 236         957  https://hamrobazaar.com/for-sale-house/house-o...
#
# [237 rows x 2 columns]

# %%
df2
# Out:
#                price      AD ID                               Location  \
# 0    रू. 2,75,00,000  HB-3EC7BB          All Core Kathmandu, Kathmandu
# 1    रू. 2,90,00,000  HB-2B4599                     Nakhipot, Lalitpur
# 2    रू. 5,75,00,000  HB-E6CF6E  Bal Kumari Marg, Kharel Tol, Lazimpat
# 3    रू. 3,10,00,000  HB-4F66A9    chabil cabahil, Chabahil, Kathmandu
# 4    रू. 2,60,00,000  HB-F62CAD               सुन्दर टोल मार्ग, सानेपा
# ..               ...        ...                                    ...
# 205  रू. 3,15,00,000  HB-7E05B6                                 Imadol
# 206  रू. 1,65,00,000  HB-355A92      Kathmandu, Bagmati Pradesh, Nepal
# 207  रू. 2,55,00,000  HB-D944E9                                 Imadol
# 208    रू. 82,00,000  HB-FD2B5B             Basantapur Area, Kathmandu
# 209  रू. 2,75,00,000  HB-979F7B              Bhaktapur City, Bhaktapur
#
#           Delivery      Negotiable     Ads Posted  Ads Expiry  \
# ...

# %%
urls_df1 = df1[~df1['URL'].isin(df2['url'])]['URL']

# %%
urls_df1
# Out:
# 210    https://hamrobazaar.com/for-sale-house/hotel-o...
# 211    https://hamrobazaar.com/for-sale-house/commerc...
# 212    https://hamrobazaar.com/for-sale-house/house-o...
# 213    https://hamrobazaar.com/for-sale-house/house-s...
# 214    https://hamrobazaar.com/for-sale-house/beautif...
# 215    https://hamrobazaar.com/for-sale-house/4-aana-...
# 216    https://hamrobazaar.com/for-sale-house/house-f...
# 217    https://hamrobazaar.com/for-sale-house/sasto-g...
# 218    https://hamrobazaar.com/for-sale-house/5aana-b...
# 219    https://hamrobazaar.com/for-sale-house/house-f...
# 220    https://hamrobazaar.com/for-sale-house/house-o...
# 221    https://hamrobazaar.com/for-sale-house/sasto-g...
# 222    https://hamrobazaar.com/for-sale-house/house-f...
# 223    https://hamrobazaar.com/for-sale-house/villa-i...
# 224    https://hamrobazaar.com/for-sale-house/14-aana...
# 225    https://hamrobazaar.com/for-sale-house/1-store...
# ...

# %%
urls_df1.to_csv('remaining2.csv')
