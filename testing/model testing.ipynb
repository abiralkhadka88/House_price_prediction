# %%
import pandas as pd
df =  pd.read_csv('NoOutliersDataSet.csv')

# %%
df = df.rename(columns={'Price(Float)': 'Price', 'Area(In Sq.Feet)': 'Area'})

# %%
df
# Out:
#             Address        Area  Road     Price  Bedroom  Bathroom
# 0          Tinthana  1711.25000   6.5  40000000        5       2.0  \
# 1        Banasthali  1027.00000   7.6  20000000        5       3.0
# 2         Kadaghari   941.18750   8.0  17500000        4       3.0
# 3             Kapan  1369.00000   8.0  22000000        3       3.0
# 4     Srijana Chowk  1129.42500   8.0  16000000        5       3.0
# ...             ...         ...   ...       ...      ...       ...
# 1902      Sukedhara  1112.31250  24.0  19000000        3       2.0
# 1903       Kharibot  1711.25000  24.0  58000000        5       5.0
# 1904          Kapan   941.18750  24.0  24500000        6       2.0
# 1905       Tinthana  2762.29975  24.0  50000000        7       3.0
# 1906       Hattiban  1262.04000  24.0  27000000        6       3.0
#
#             Face  Floors       City
# 0          North     2.0  Kathmandu
# 1          North     2.5  Kathmandu
# 2          South     2.5  Kathmandu
# ...

# %%
df.to_csv('outliers_cleaned.csv')
